# %%
import pandas as pd
import os
import quandl
import time

# %%
auth_tok = "nrEHd32tMgesWjRx25KQ"

# %%
path = "/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter"

# %%
def Stock_Prices():
    df = pd.DataFrame()

    statspath = path+'/_KeyStats'
    stock_list = [x[0] for x in os.walk(statspath)]

    print(stock_list)

    for each_dir in stock_list[1:20]:
        try:
            ticker = each_dir.split("/")[-1]
            print(ticker)
            name = "WIKI/"+ticker.upper()
            data = quandl.get(name,
                              trim_start = "2000-12-12",
                              trim_end = "2014-12-30",
                              authtoken=auth_tok)
            data[ticker.upper()] = data["Adj. Close"]
            df = pd.concat([df, data[ticker.upper()]], axis = 1)

        except Exception as e:
            print(str(e))
            time.sleep(10)
            try:
                ticker = each_dir.split("/")[-1]
                print(ticker)
                name = "WIKI/"+ticker.upper()
                data = quandl.get(name,
                                  trim_start = "2000-12-12",
                                  trim_end = "2014-12-30",
                                  authtoken=auth_tok)
                data[ticker.upper()] = data["Adj. Close"]
                df = pd.concat([df, data[ticker.upper()]], axis = 1)

            except Exception as e:
                print(str(e))

    df.to_csv("stock_prices.csv")

# %%
Stock_Prices()
# Out:
# ['/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/a', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aa', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aapl', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/abbv', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/abc', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/abt', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/ace', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aci', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/acn', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/act', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/adbe', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/adi', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/adm', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/adp', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/adsk', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/adt', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aee', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aeo', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aep', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aes', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aet', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/afl', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/agn', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aig', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aiv', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aiz', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/akam', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/all', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/altr', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/alxn', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/amat', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/amd', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/amgn', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/amp', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/amt', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/amzn', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/an', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/anf', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/ann', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/aon', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/apa', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/apc', '/Users/henry/Documents/github/ml_with_scikit_learn_n_python/intraQuarter/_KeyStats/apd', '/Users/henry/Documents/github/ml_wit ...
# a
# aa
# aapl
# abbv
# abc
# abt
# ace
# aci
# acn
# act
# (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# act
# (Status 404) (Quandl Error QECx02) You have submitted an incorrect Quandl code. Please check your Quandl codes and try again.
# adbe
# adi
# adm
# adp
# adsk
# adt
# aee
# aeo
# aep
